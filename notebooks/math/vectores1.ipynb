# %% [markdown]
# # Vectores, rectas, planos y superficies en el espacio

# %% [markdown]
# ## VECTORES EN EL PLANO

# %% [markdown]
# **Definición de vector en el plano**
# *Un **vector en el plano** es un par ordenado de números reales (X, Y). Los números X y Y son los **componentes** del vector (X, Y).*

# %%
def add_numbers(a,b):
    """add two numbers together
    returns
    the sum : type of arguments"""
    return a + b

# %%
add_numbers(3,3)
# Out:
# 6

# %%
add_numbers?
# Out:
# Signature: add_numbers(a, b)
# Docstring:
# add two numbers together
# returns
# the sum : type of arguments
# File:      c:\users\krist\appdata\local\temp\ipykernel_25476\2640209440.py
# Type:      function

# %%
import numpy as np
np.*load*?
# Out:
# np.__loader__
# np.load
# np.loadtxt

# %%
a=[1,2,3]
b=a
a.append(4)
b
# Out:
# [1, 2, 3, 4]

# %%
ival=17239871
ival**6
# Out:
# 26254519291092456596965462913230729701102721

# %%
from datetime import datetime, date, time
dt=datetime(2011,10,29,20,30,21)
dt.time()
# Out:
# datetime.time(20, 30, 21)
